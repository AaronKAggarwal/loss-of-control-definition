# %% [markdown]
# # 03 — Task 1B: Attribute Identification
#
# Runs Prompt 1b on the consolidated verified extractions from Task 1A. Identifies recurring defining attributes across all papers.
#
# **Prerequisites:**
# 1. Run `02_task_1a.ipynb` to get extraction outputs.
# 2. Complete human review of 1A outputs.
# 3. Place verified extractions in `stages/1a_.../verified/consolidated_verified.json` on Drive.
#
# **Status:** `run_1b` is not yet implemented. This notebook is a stub.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount("/content/drive")

# %%
# Clone or pull the repo
import os

REPO_URL = "https://github.com/YOUR_USERNAME/loss-of-control-definition.git"  # TODO: update
REPO_DIR = "/content/loss-of-control-definition"

if os.path.exists(REPO_DIR):
    # !cd {REPO_DIR} && git pull
else:
    # !git clone {REPO_URL} {REPO_DIR}

# %%
# Install dependencies
# !pip install -r /content/loss-of-control-definition/requirements.txt -q

# %%
# Path setup
import sys
sys.path.insert(0, REPO_DIR)

DRIVE_ROOT = "/content/drive/MyDrive/loc_definition_project"

# %%
# HuggingFace token from Colab secrets
from google.colab import userdata
HF_TOKEN = userdata.get("HF_TOKEN")

# %%
# Experiment config — edit these values for each run
config = {
    "experiment": "exp001_baseline",
    "model": "meta-llama/Meta-Llama-3.1-70B-Instruct",
    "temperature": 0.1,
    "prompt_version": "prompt_1b_v1",
}

# %%
# Run Task 1B (not yet implemented)
from src.run_stage import run_1b

# run_1b(config, DRIVE_ROOT, HF_TOKEN)
print("run_1b is not yet implemented. Blocked on human review of 1A outputs.")
