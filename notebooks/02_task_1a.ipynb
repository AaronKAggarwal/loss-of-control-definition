# %% [markdown]
# # 02 — Task 1A: Definition Extraction
#
# Runs Prompt 1a against each paper in the corpus individually. For each paper, the model extracts every passage where the authors define or characterise "loss of control" or related concepts.
#
# **Prerequisites:** Run `01_extract_text.ipynb` first so `raw_text/{paper_id}.txt` files exist on Drive.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount("/content/drive")

# %%
# Clone or pull the repo
import os

REPO_URL = "https://github.com/AaronKAggarwal/loss-of-control-definition.git"
REPO_DIR = "/content/loss-of-control-definition"

if os.path.exists(REPO_DIR):
    # !cd {REPO_DIR} && git pull
else:
    # !git clone {REPO_URL} {REPO_DIR}

# %%
# Install dependencies
# !pip install -r /content/loss-of-control-definition/requirements.txt -q

# %%
# Path setup
import sys
sys.path.insert(0, REPO_DIR)

DRIVE_ROOT = "/content/drive/MyDrive/loc_definition_project"

# %%
# HuggingFace token from Colab secrets
from google.colab import userdata
HF_TOKEN = userdata.get("HF_TOKEN")

# %%
# Experiment config — edit these values for each run
config = {
    "experiment": "exp001_baseline",
    "model": "meta-llama/Llama-3.1-8B-Instruct",
    "provider": "nscale",
    "temperature": 0.1,
    "prompt_version": "prompt_1a_v1",
    "seed_terms_version": "v1",
}

# %%
# Run Task 1A
from src.run_stage import run_1a

run_1a(config, DRIVE_ROOT, HF_TOKEN, repo_root=REPO_DIR)

# %%
# Generate review docs, summary CSV, and consolidated JSON
from src.generate_review import generate_review_docs

generate_review_docs(config, DRIVE_ROOT, repo_root=REPO_DIR)

# %%
# Display summary
import pandas as pd

summary_path = os.path.join(
    DRIVE_ROOT, "stages", "1a_definition_extraction",
    "experiments", config["experiment"], "summary.csv",
)
df = pd.read_csv(summary_path)
df
